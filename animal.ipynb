# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.171-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached matplotlib-3.10.5-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached scipy-1.16.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.7.1-cp313-cp313-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.22.1-cp313-cp313-win_amd64.whl.metadata (6.1 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...

# %%
import cv2
import time
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("❌ Error: Could not open webcam.")
    exit()

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = 20

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_annotated2.mp4', fourcc, fps, (frame_width, frame_height))

print("✅ Webcam activated. Starting detection...")

prev_time = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, verbose=False)[0]

    for box in results.boxes:
        cls_id = int(box.cls[0])
        class_name = model.names[cls_id]
        conf = float(box.conf[0])
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        label = f"{class_name} {conf:.2f}"

        print(f"Detected: {class_name} | Confidence: {conf:.2f} | Box: ({x1}, {y1}), ({x2}, {y2})")

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    curr_time = time.time()
    fps_disp = 1 / (curr_time - prev_time)
    prev_time = curr_time
    cv2.putText(frame, f"FPS: {fps_disp:.2f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    out.write(frame)

    cv2.imshow("YOLOv8 Detection - Webcam", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
print("🛑 Detection stopped. Output saved to `output_annotated.mp4`")
# Out:
# ✅ Webcam activated. Starting detection...
# Detected: person | Confidence: 0.94 | Box: (55, 128), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (55, 128), (473, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 128), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 128), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 127), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 128), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 128), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (54, 131), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (55, 131), (474, 479)
# Detected: person | Confidence: 0.94 | Box: (55, 131), (474, 479)
# Detected: person | Confidence: 0.93 | Box: (55, 131), (474, 479)
# Detected: person | Confidence: 0.93 | Box: (55, 130), (473, 478)
# Detected: person | Confidence: 0.93 | Box: (56, 131), (474, 479)
# Detected: person | Confidence: 0.93 | Box: (55, 130), (473, 478)
# ...
